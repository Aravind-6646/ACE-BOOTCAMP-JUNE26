# %% [markdown]
# <a href="https://colab.research.google.com/github/Aravind-6646/ACE-BOOTCAMP-JUNE26/blob/main/Pandas_Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
import pandas as pd
dframe=pd.read_csv('usedcars.csv')
print(dframe)
# Out:
#             Brand      Model  Year  Mileage_kmpl    Engine_CC  Horsepower  \
# 0          Toyota      Camry  2001     19.615852  1396.560379         NaN
# 1         Hyundai        i20  2012     19.478608  1130.771005  137.021719
# 2        Mahindra     Bolero  2008     17.469920  1766.466250  142.902960
# 3             BMW         X1  2015     21.295421          NaN   49.782079
# 4           Honda      Civic  2022     18.326833  1239.334935  121.505993
# ...           ...        ...   ...           ...          ...         ...
# 1004995    Nissan    Magnite  2022     12.256422  1773.657889  117.574596
# 1004996     Honda      Amaze  2005           NaN  1705.773023   99.643689
# 1004997     Skoda    Octavia  2018     21.665335  1447.159515         NaN
# 1004998       BMW         X3  2010     17.852635  2179.906631         NaN
# 1004999      Ford  Endeavour  2010     20.839002   800.000000   11.857082
#
#         Fuel_Type Transmission Owner_Type  Color       City  Kms_Driven  \
# ...

# %%
dframe
# Out:
#             Brand      Model  Year  Mileage_kmpl    Engine_CC  Horsepower  \
# 0          Toyota      Camry  2001     19.615852  1396.560379         NaN
# 1         Hyundai        i20  2012     19.478608  1130.771005  137.021719
# 2        Mahindra     Bolero  2008     17.469920  1766.466250  142.902960
# 3             BMW         X1  2015     21.295421          NaN   49.782079
# 4           Honda      Civic  2022     18.326833  1239.334935  121.505993
# ...           ...        ...   ...           ...          ...         ...
# 1004995    Nissan    Magnite  2022     12.256422  1773.657889  117.574596
# 1004996     Honda      Amaze  2005           NaN  1705.773023   99.643689
# 1004997     Skoda    Octavia  2018     21.665335  1447.159515         NaN
# 1004998       BMW         X3  2010     17.852635  2179.906631         NaN
# 1004999      Ford  Endeavour  2010     20.839002   800.000000   11.857082
#
#         Fuel_Type Transmission Owner_Type  Color       City  Kms_Driven  \
# ...

# %%
import pandas as pd

df = pd.read_csv("usedcars.csv")
print(df.shape)
print(df.columns)
# Out:
# (1005000, 20)
# Index(['Brand', 'Model', 'Year', 'Mileage_kmpl', 'Engine_CC', 'Horsepower',
#        'Fuel_Type', 'Transmission', 'Owner_Type', 'Color', 'City',
#        'Kms_Driven', 'Insurance_Valid', 'Service_History', 'Accidents',
#        'Tax_Paid', 'Number_of_Doors', 'Seats', 'Registration_Age', 'Price'],
#       dtype='object')

# %%
fi=dframe['Brand']=='Toyota'
dframe.loc[fi]
# Out:
#           Brand    Model  Year  Mileage_kmpl    Engine_CC  Horsepower  \
# 0        Toyota    Camry  2001     19.615852  1396.560379         NaN
# 5        Toyota    Camry  2007           NaN  1513.157430  100.927306
# 11       Toyota    Camry  2016           NaN  1553.812047   97.547550
# 18       Toyota    Camry  2006     15.258648  1759.413790  139.156544
# 25       Toyota    Yaris  2016           NaN  1694.915565  146.259864
# ...         ...      ...   ...           ...          ...         ...
# 1004942  Toyota    Yaris  2005           NaN  1197.099021   88.327370
# 1004960  Toyota  Corolla  2008     12.783504   988.490276  105.179968
# 1004963  Toyota    Yaris  2014     18.126993  1006.904721   74.740377
# 1004974  Toyota    Camry  2004     21.289970  2102.058655  176.965808
# 1004977  Toyota  Corolla  2001     20.786378  1728.841702  172.839808
#
#         Fuel_Type Transmission Owner_Type  Color       City  Kms_Driven  \
# ...

# %%
fi=dframe['Brand']=='Toyota'
dframe.loc[fi].head(10)
# Out:
#       Brand    Model  Year  Mileage_kmpl    Engine_CC  Horsepower Fuel_Type  \
# 0    Toyota    Camry  2001     19.615852  1396.560379         NaN    Hybrid
# 5    Toyota    Camry  2007           NaN  1513.157430  100.927306    Petrol
# 11   Toyota    Camry  2016           NaN  1553.812047   97.547550    Petrol
# 18   Toyota    Camry  2006     15.258648  1759.413790  139.156544    Petrol
# 25   Toyota    Yaris  2016           NaN  1694.915565  146.259864    Petrol
# 45   Toyota    Camry  2012     24.715593  1439.234695  145.272997    Diesel
# 78   Toyota  Corolla  2002     19.375264  1938.788070  162.223557    Diesel
# 84   Toyota    Camry  2011     18.207507  1851.570601  150.787928    Diesel
# 91   Toyota    Camry  2019           NaN          NaN  184.158352    Petrol
# 107  Toyota    Camry  2007           NaN  1954.181684  165.002483    Hybrid
#
#     Transmission Owner_Type  Color       City  Kms_Driven  Insurance_Valid  \
# ...

# %%
flit=(dframe['Brand']=='Toyota')
dframe.loc[flit].sort_index(ascending=False).head(10)
# Out:
#           Brand    Model  Year  Mileage_kmpl    Engine_CC  Horsepower  \
# 1004977  Toyota  Corolla  2001     20.786378  1728.841702  172.839808
# 1004974  Toyota    Camry  2004     21.289970  2102.058655  176.965808
# 1004963  Toyota    Yaris  2014     18.126993  1006.904721   74.740377
# 1004960  Toyota  Corolla  2008     12.783504   988.490276  105.179968
# 1004942  Toyota    Yaris  2005           NaN  1197.099021   88.327370
# 1004918  Toyota    Camry  2018     18.237145  1681.705667         NaN
# 1004912  Toyota    Yaris  2002     20.906947  1503.314227  130.840634
# 1004910  Toyota    Camry  2008     25.708823  1585.480548         NaN
# 1004887  Toyota    Camry  2004     19.149227  2180.863081  188.146689
# 1004884  Toyota  Corolla  2005     16.667552  1255.562044  118.458319
#
#         Fuel_Type Transmission Owner_Type  Color       City  Kms_Driven  \
# 1004977    Diesel       Manual     Second  Black  Hyderabad      373512
# ...

# %%
flit=(dframe['Brand']=='Toyota') & (dframe['City']=='Hyderabad') & (dframe['Fuel_Type']=='CNG')
dframe.loc[flit].sort_index(ascending=False).head(5)
# Out:
#          Brand    Model  Year  Mileage_kmpl    Engine_CC  Horsepower  \
# 999279  Toyota    Yaris  2012     17.125495  1240.563335   90.673276
# 998805  Toyota    Camry  2017     15.527558  1067.298489   53.323059
# 998761  Toyota    Yaris  2023           NaN  1925.353481  157.153893
# 997268  Toyota  Corolla  2022     13.010858  2038.098884  160.610667
# 996993  Toyota    Yaris  2017     19.000076  1252.603430   87.769745
#
#        Fuel_Type Transmission Owner_Type  Color       City  Kms_Driven  \
# 999279       CNG       Manual      First  Black  Hyderabad      276419
# 998805       CNG    Automatic      First    Red  Hyderabad       94216
# 998761       CNG       Manual      First  Black  Hyderabad       42882
# 997268       CNG          NaN      First   Blue  Hyderabad       67890
# 996993       CNG       Manual      First    NaN  Hyderabad       71144
#
#         Insurance_Valid  Service_History  Accidents  Tax_Paid  \
# ...
